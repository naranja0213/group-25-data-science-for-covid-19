# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #Import 3 data set

# %%
#vaccination progress
vaccination_progress=pd.read_csv("country vaccinations.csv")

# %%
#death ratio and incident rate
c=pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/09-21-2021.csv")

# %%
#testing progress
test_progress=pd.read_csv("covid-testing.csv")

# %%
vaccination_progress.info()
vaccination_progress.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36063 entries, 0 to 36062
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              36063 non-null  object
#  1   iso_code                             36063 non-null  object
#  2   date                                 36063 non-null  object
#  3   total_vaccinations                   20068 non-null  float64
#  4   people_vaccinated                    19150 non-null  float64
#  5   people_fully_vaccinated              16302 non-null  float64
#  6   daily_vaccinations_raw               16553 non-null  float64
#  7   daily_vaccinations                   35825 non-null  float64
#  8   total_vaccinations_per_hundred       20068 non-null  float64
#  9   people_vaccinated_per_hundred        19150 non-null  float64
#  10  people_fully_vaccinated_per_hundred  16302 non-null  float64
# ...

# %%
vaccination_progress
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 36058     Zimbabwe      ZWE  2021-07-31           2413509.0
# 36059     Zimbabwe      ZWE  2021-08-01           2433341.0
# 36060     Zimbabwe      ZWE  2021-08-02           2473590.0
# 36061     Zimbabwe      ZWE  2021-08-03           2540555.0
# 36062     Zimbabwe      ZWE  2021-08-04           2604265.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
c.info()
c.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3988 entries, 0 to 3987
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3267 non-null   float64
#  1   Admin2               3272 non-null   object
#  2   Province_State       3814 non-null   object
#  3   Country_Region       3988 non-null   object
#  4   Last_Update          3988 non-null   object
#  5   Lat                  3899 non-null   float64
#  6   Long_                3899 non-null   float64
#  7   Confirmed            3988 non-null   int64
#  8   Deaths               3988 non-null   int64
#  9   Recovered            0 non-null      float64
#  10  Active               0 non-null      float64
#  11  Combined_Key         3988 non-null   object
#  12  Incident_Rate        3898 non-null   float64
#  13  Case_Fatality_Ratio  3947 non-null   float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 436.3+ KB
# ...

# %%
c
# Out:
#       FIPS Admin2 Province_State      Country_Region          Last_Update  \
# 0      NaN    NaN            NaN         Afghanistan  2021-09-22 04:21:45
# 1      NaN    NaN            NaN             Albania  2021-09-22 04:21:45
# 2      NaN    NaN            NaN             Algeria  2021-09-22 04:21:45
# 3      NaN    NaN            NaN             Andorra  2021-09-22 04:21:45
# 4      NaN    NaN            NaN              Angola  2021-09-22 04:21:45
# ...    ...    ...            ...                 ...                  ...
# 3983   NaN    NaN            NaN             Vietnam  2021-09-22 04:21:45
# 3984   NaN    NaN            NaN  West Bank and Gaza  2021-09-22 04:21:45
# 3985   NaN    NaN            NaN               Yemen  2021-09-22 04:21:45
# 3986   NaN    NaN            NaN              Zambia  2021-09-22 04:21:45
# 3987   NaN    NaN            NaN            Zimbabwe  2021-09-22 04:21:45
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# ...

# %%
test_progress.info()
test_progress.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64187 entries, 0 to 64186
# Data columns (total 14 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Entity                                         64187 non-null  object
#  1   ISO code                                       64187 non-null  object
#  2   Date                                           64187 non-null  object
#  3   Source URL                                     55026 non-null  object
#  4   Source label                                   55224 non-null  object
#  5   Notes                                          7062 non-null   object
#  6   Daily change in cumulative total               52705 non-null  float64
#  7   Cumulative total                               52588 non-null  float64
#  8   Cumulative total per thousand                  52588 non-null  float64
# ...

# %%
test_progress
# Out:
#                            Entity ISO code        Date  \
# 0       Albania - tests performed      ALB  2020-02-25
# 1       Albania - tests performed      ALB  2020-02-26
# 2       Albania - tests performed      ALB  2020-02-27
# 3       Albania - tests performed      ALB  2020-02-28
# 4       Albania - tests performed      ALB  2020-02-29
# ...                           ...      ...         ...
# 64182  Zimbabwe - tests performed      ZWE  2021-09-15
# 64183  Zimbabwe - tests performed      ZWE  2021-09-16
# 64184  Zimbabwe - tests performed      ZWE  2021-09-17
# 64185  Zimbabwe - tests performed      ZWE  2021-09-18
# 64186  Zimbabwe - tests performed      ZWE  2021-09-19
#
#                                               Source URL  \
# 0      https://shendetesia.gov.al/koronavirusi-mshms-...
# 1      https://shendetesia.gov.al/fond-shtese-per-mas...
# 2      https://shendetesia.gov.al/ministria-e-shendet...
# 3      http://shendetesia.gov.al/manastirliu-asnje-ra...
# ...

# %%
c.to_csv("c.csv")#导出新csv文件

# %%
#check and clean data

# %%
#EDA

# %%
#data visuarization

# %%
#prediction time series

# %%
#evaluation

# %%
#make sulotion
